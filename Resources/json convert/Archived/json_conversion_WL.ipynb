# %%
import pandas as pd
import json

# %%
# import
file = "triage_levels.csv"
import_df = pd.read_csv(file, index_col=False)
import_df.head(5)
# Out:
#    xray_number       image_index  patient_id  age gender view_position  \
# 0            1  00000001_000.png           1   58      M            PA
# 1            2  00000001_001.png           1   58      M            PA
# 2            3  00000001_002.png           1   58      M            PA
# 3            4  00000002_000.png           2   81      M            PA
# 4            5  00000003_000.png           3   81      F            PA
#
#    highest_class highest_label
# 0              2         Acute
# 1              2         Acute
# 2              3      Emergent
# 3              0    No Finding
# 4              1       Chronic

# %%
# Slice the DF to sample
tester = import_df.head()
tester
# Out:
#    xray_number       image_index  patient_id  age gender view_position  \
# 0            1  00000001_000.png           1   58      M            PA
# 1            2  00000001_001.png           1   58      M            PA
# 2            3  00000001_002.png           1   58      M            PA
# 3            4  00000002_000.png           2   81      M            PA
# 4            5  00000003_000.png           3   81      F            PA
#
#    highest_class highest_label
# 0              2         Acute
# 1              2         Acute
# 2              3      Emergent
# 3              0    No Finding
# 4              1       Chronic

# %%
# Convert thee to a JSON using the Table Format to orient. 
# The layout will look slightly different but each sample is stored in a list as a dictionary with all the column names as keys. 
# There is a schema dictionary object at the top that informs you on the data type of the columns but you can totally ignore it. 

result = tester.to_json(path_or_buf="fuckme.json", orient='table', indent=4, index=False)
